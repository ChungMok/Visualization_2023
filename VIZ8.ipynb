# %%
import matplotlib.pyplot as pltb
import numpy as np

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))
 
fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=30, length=10, width=3)
ax.hist(data)
# Out:
# (array([  7.,  14.,  45.,  80., 108.,  99.,  80.,  36.,  22.,   9.]),
#  array([-2.77259276, -2.22571108, -1.67882939, -1.13194771, -0.58506603,
#         -0.03818435,  0.50869733,  1.05557901,  1.60246069,  2.14934237,
#          2.69622405]),
#  <BarContainer object of 10 artists>)

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=30, length=10, width=3)
ax.hist(data, facecolor='skyblue', edgecolor='darkblue', linewidth=3, hatch='//')
# Out:
# (array([  7.,  14.,  45.,  80., 108.,  99.,  80.,  36.,  22.,   9.]),
#  array([-2.77259276, -2.22571108, -1.67882939, -1.13194771, -0.58506603,
#         -0.03818435,  0.50869733,  1.05557901,  1.60246069,  2.14934237,
#          2.69622405]),
#  <BarContainer object of 10 artists>)

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))
 
fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=30, length=10, width=3)

freqs, bin_edges, rects = ax.hist(data)
print(freqs)
print(bin_edges)
print(rects)
# Out:
# [  7.  14.  45.  80. 108.  99.  80.  36.  22.   9.]
# [-2.77259276 -2.22571108 -1.67882939 -1.13194771 -0.58506603 -0.03818435
#   0.50869733  1.05557901  1.60246069  2.14934237  2.69622405]
# <BarContainer object of 10 artists>

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))
 
fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=30, length=10, width=3)

freqs, bin_edges, rects = ax.hist(data)

bin_centers = (bin_edges[:-1] + bin_edges[1:])/2
ax.set_xticks(bin_centers)
ax.set_xticklabels(np.around(bin_centers, 2), rotation=30)
# Out:
# [Text(-2.499151915977139, 0, '-2.5'),
#  Text(-1.9522702350781156, 0, '-1.95'),
#  Text(-1.4053885541790927, 0, '-1.41'),
#  Text(-0.8585068732800696, 0, '-0.86'),
#  Text(-0.3116251923810467, 0, '-0.31'),
#  Text(0.23525648851797643, 0, '0.24'),
#  Text(0.7821381694169995, 0, '0.78'),
#  Text(1.3290198503160224, 0, '1.33'),
#  Text(1.8759015312150455, 0, '1.88'),
#  Text(2.4227832121140684, 0, '2.42')]

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=30, length=10, width=3)

ax.hist(data, facecolor='skyblue', edgecolor='darkblue', linewidth=3)
ax.hist(data, bins=20, facecolor='coral', edgecolor='red', linewidth=3)
# 너무 잘게 자르면 히스토그램처럼 보이지 않음
# Out:
# (array([ 5.,  2.,  7.,  7., 21., 24., 35., 45., 53., 55., 47., 52., 42.,
#         38., 22., 14., 12., 10.,  8.,  1.]),
#  array([-2.77259276, -2.49915192, -2.22571108, -1.95227024, -1.67882939,
#         -1.40538855, -1.13194771, -0.85850687, -0.58506603, -0.31162519,
#         -0.03818435,  0.23525649,  0.50869733,  0.78213817,  1.05557901,
#          1.32901985,  1.60246069,  1.87590153,  2.14934237,  2.42278321,
#          2.69622405]),
#  <BarContainer object of 20 artists>)

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))

fig, axes = plt.subplots(2, 1, figsize=(14, 20))
axes[0].tick_params(labelsize=20)
axes[1].tick_params(labelsize=20)

axes[0].hist(data, bins=20)
axes[1].hist(data, bins=20, density=True)
# Out:
# (array([0.03657098, 0.01462839, 0.05119937, 0.05119937, 0.15359812,
#         0.17554071, 0.25599687, 0.32913884, 0.38765241, 0.4022808 ,
#         0.34376723, 0.38033821, 0.30719625, 0.27793946, 0.16091232,
#         0.10239875, 0.08777036, 0.07314196, 0.05851357, 0.0073142 ]),
#  array([-2.77259276, -2.49915192, -2.22571108, -1.95227024, -1.67882939,
#         -1.40538855, -1.13194771, -0.85850687, -0.58506603, -0.31162519,
#         -0.03818435,  0.23525649,  0.50869733,  0.78213817,  1.05557901,
#          1.32901985,  1.60246069,  1.87590153,  2.14934237,  2.42278321,
#          2.69622405]),
#  <BarContainer object of 20 artists>)

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=20)

ax.hist(data, bins=20, cumulative=True)
# Out:
# (array([  5.,   7.,  14.,  21.,  42.,  66., 101., 146., 199., 254., 301.,
#         353., 395., 433., 455., 469., 481., 491., 499., 500.]),
#  array([-2.77259276, -2.49915192, -2.22571108, -1.95227024, -1.67882939,
#         -1.40538855, -1.13194771, -0.85850687, -0.58506603, -0.31162519,
#         -0.03818435,  0.23525649,  0.50869733,  0.78213817,  1.05557901,
#          1.32901985,  1.60246069,  1.87590153,  2.14934237,  2.42278321,
#          2.69622405]),
#  <BarContainer object of 20 artists>)

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(14, 20))
ax.tick_params(labelsize=20)

ax.hist(data, orientation='horizontal')
# Out:
# (array([  7.,  14.,  45.,  80., 108.,  99.,  80.,  36.,  22.,   9.]),
#  array([-2.77259276, -2.22571108, -1.67882939, -1.13194771, -0.58506603,
#         -0.03818435,  0.50869733,  1.05557901,  1.60246069,  2.14934237,
#          2.69622405]),
#  <BarContainer object of 10 artists>)

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(14, 20))
ax.tick_params(labelsize=20)

ax.hist(data, rwidth=0.8)
# Out:
# (array([  7.,  14.,  45.,  80., 108.,  99.,  80.,  36.,  22.,   9.]),
#  array([-2.77259276, -2.22571108, -1.67882939, -1.13194771, -0.58506603,
#         -0.03818435,  0.50869733,  1.05557901,  1.60246069,  2.14934237,
#          2.69622405]),
#  <BarContainer object of 10 artists>)

# %%
np.random.seed(0)

n_data = 500
data = np.random.normal(0, 1, (n_data, ))

fig, ax = plt.subplots(figsize=(14, 20))
ax.tick_params(labelsize=20)

freqs, bin_edges, rects = ax.hist(data, rwidth=0.5, align='mid')

bin_centers = (bin_edges[:-1] + bin_edges[1:])/2
ax.set_xticks(bin_centers)
ax.set_xticks(bin_edges, minor=True)

ax.grid(axis='x', which='major', linewidth=3)
ax.grid(axis='x', which='minor', linewidth=3, linestyle=':')

# %%
np.random.seed(0)

n_data1, n_data2 = 300, 300
data1 = np.random.normal(0, 1, (n_data1,))
data2 = np.random.normal(5, 3, (n_data2,))

fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=20)

data = np.hstack((data1,data2))
m_val, M_val = data.min(), data.max()

data_loc = np.linspace(m_val, M_val, 31)

ax.hist(data1, bins=data_loc, alpha=0.5)
ax.hist(data2, bins=data_loc, alpha=0.5)
# Out:
# (array([ 1.,  1.,  3.,  3.,  4.,  3.,  5.,  7.,  8., 10., 15., 15., 19.,
#         23., 29., 23., 22., 22., 17., 13., 21., 11.,  6.,  7.,  6.,  1.,
#          2.,  1.,  1.,  1.]),
#  array([-4.13842916, -3.56419245, -2.98995574, -2.41571903, -1.84148232,
#         -1.26724561, -0.6930089 , -0.11877219,  0.45546452,  1.02970123,
#          1.60393794,  2.17817465,  2.75241136,  3.32664808,  3.90088479,
#          4.4751215 ,  5.04935821,  5.62359492,  6.19783163,  6.77206834,
#          7.34630505,  7.92054176,  8.49477847,  9.06901518,  9.64325189,
#         10.2174886 , 10.79172531, 11.36596203, 11.94019874, 12.51443545,
#         13.08867216]),
#  <BarContainer object of 30 artists>)

# %%
n_class = 2
n_data = 300

data = np.random.normal(0, 1, (n_data, n_class))

fig, ax = plt.subplots(figsize=(14, 10))
ax.hist(data)
# Out:
# (array([[ 1.,  9., 21., 59., 70., 77., 35., 20.,  6.,  2.],
#         [ 3., 11., 34., 49., 80., 61., 39., 16.,  6.,  1.]]),
#  array([-2.83455451, -2.23400158, -1.63344865, -1.03289572, -0.43234279,
#          0.16821013,  0.76876306,  1.36931599,  1.96986892,  2.57042185,
#          3.17097477]),
#  <a list of 2 BarContainer objects>)

# %%
n_data = 300
n_class = 3

data = np.random.normal(0, 1, (n_data, n_class))

fig, ax = plt.subplots(figsize=(14, 10))

ax.hist(data, bins=15, color=['coral', 'royalblue', 'purple'], label = ['data1', 'data2', 'data3'])
ax.legend(fontsize=30)

# %%
np.random.seed(0)

n_class = 2
n_data = 300

data = np.random.normal(0, 1, (n_data, n_class))

fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=20)

freqs, bin_edges, rects = ax.hist(data)

print(freqs.shape)
print(bin_edges.shape)
print(rects)
print(rects[0])
print(rects[1])
# Out:
# (2, 10)
# (11,)
# <a list of 2 BarContainer objects>
# <BarContainer object of 10 artists>
# <BarContainer object of 10 artists>

# %%
from scipy import stats

n_data = 300
data = np.random.normal(0, 1, (n_data, ))

m_val, M_val = data.min(), data.max()
estimator_x = np.linspace(m_val, M_val, 100)

kde_estimator = stats.gaussian_kde(data)
kde = kde_estimator(estimator_x)

fig, ax = plt.subplots(figsize=(14, 10))
ax.tick_params(labelsize=20)
ax.hist(data, alpha=0.5, density=True)
ax.plot(estimator_x, kde)

# %%
def kde_estimation(data, est_x, n_data, bin_interval):
    estimator = stats.gaussian_kde(data)
    kde = estimator(est_x)
    kde = kde * n_data * bin_interval
    return kde

n_data_list = [300, 500]
data1 = np.random.normal(0, 1, (n_data_list[0],))
data2 = np.random.normal(5, 1, (n_data_list[1],))
data = np.array([data1, data2], dtype=object)

m_val, M_val = None, None
for class_idx in range(len(data)):
    t_data = data[class_idx]
    
    if m_val == None or t_data.min() < m_val:
        m_val = t_data.min()
        
    if M_val == None or t_data.max() > M_val:
        M_val = t_data.max()
        
estimator_x = np.linspace(m_val, M_val, 500)

fig, ax = plt.subplots(figsize=(25, 15))
ax.tick_params(labelsize=30)

bin_interval = bin_edges[1] - bin_edges[0]
colors = ['coral', 'royalblue']

freqs, bin_edges, rects = ax.hist(data, bins=20, color=colors)

for class_idx in range(2):
    t_data = data[class_idx]
    
    K = kde_estimation(t_data, estimarot_x, n_data_list[class_idx], bin_interval)
    
    ax.plot(estimator_x, K, color = colors[class_idx])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7212/3211238244.py in <module>
#      35     K = kde_estimation(t_data, estimarot_x, n_data_list[class_idx], bin_interval)
#      36
# ---> 37     ax.plot(estimator_x, K, color = colors[class_idx])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# ...
